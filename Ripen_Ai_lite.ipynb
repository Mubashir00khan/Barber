# %% [markdown]
# <a href="https://colab.research.google.com/github/Mubashir00khan/Barber/blob/main/Ripen_Ai_lite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.8/898.8 kB 16.4 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.6/107.7 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="8Z8dg9ILJ47TSeX7tpPN")
project = rf.workspace("ripen-ai").project("ripen-ai-lite")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Ripen-Ai-lite-2 in yolov11:: 100%|██████████| 210/210 [00:00<00:00, 5715.20it/s]

# %%
# !yolo task=detect mode=train data=/content/Ripen-Ai-lite-2/data.yaml model="yolo11n.pt" epochs=40 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 5.35M/5.35M [00:00<00:00, 109MB/s]
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.8/898.8 kB 24.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLO11n model
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Run inference with the YOLO11n model on the 'bu/Ripens.jpg' image
results = model("/content/Ripen-Ai-lite-2/dates3.png", save=True)
# Out:
# image 1/1 /content/Ripen-Ai-lite-2/dates3.png: 384x640 6 khalals, 45.4ms
# Speed: 1.6ms preprocess, 45.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict7
